# %%
import pandas as pd
import numpy as np

# %%
m1=pd.read_csv('3.2.1PandaMovies.csv')
m1.head(50)
# Out:
#     star_rating                                              title  \
# 0           9.3                           The Shawshank Redemption
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 3           9.0                                    The Dark Knight
# 4           8.9                                       Pulp Fiction
# 5           8.9                                       12 Angry Men
# 6           8.9                     The Good, the Bad and the Ugly
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
m1.index
# Out:
# RangeIndex(start=0, stop=979, step=1)

# %%
m1.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
m1.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
m1.shape
# Out:
# (979, 6)

# %%
m1.genre.value_counts() # data define according to genre
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
# model preparing or data preparation

# %%
m1[(m1.genre=='Drama') & (m1.duration>200)] # seprtae drama genre movie according to duration
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
m1.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
m1.actors_list[0]
# Out:
# "[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']"

# %%
m1.title.str.upper().head() # change upper case of the strings
# Out:
# 0    THE SHAWSHANK REDEMPTION
# 1               THE GODFATHER
# 2      THE GODFATHER: PART II
# 3             THE DARK KNIGHT
# 4                PULP FICTION
# Name: title, dtype: object

# %%
m1[m1.title.str.contains('godfather',case=False)]
# Out:
#      star_rating                    title content_rating  genre  duration  \
# 1            9.2            The Godfather              R  Crime       175
# 2            9.1   The Godfather: Part II              R  Crime       200
# 711          7.6  The Godfather: Part III              R  Crime       162
#
#                                            actors_list
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 711    [u'Al Pacino', u'Diane Keaton', u'Andy Garcia']

# %%
# if god father cantnot find due to case-sensitive of the movie name then we have to do [case=False] then it doesnot case sensitive

# %%
m1[m1.title.str.contains('dark knight',case=False)]
# Out:
#     star_rating                  title content_rating   genre  duration  \
# 3           9.0        The Dark Knight          PG-13  Action       152
# 43          8.5  The Dark Knight Rises          PG-13  Action       165
#
#                                           actors_list
# 3   [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 43  [u'Christian Bale', u'Tom Hardy', u'Anne Hatha...

# %%
m1[m1.star_rating.between(7,8)]
# Out:
#      star_rating                                            title  \
# 297          8.0                                             Rope
# 298          8.0                                     The Graduate
# 299          8.0                                    Jurassic Park
# 300          8.0                                         Dogville
# 301          8.0                                        Furious 7
# 302          8.0                                           Patton
# 303          8.0                   The Nightmare Before Christmas
# 304          8.0                                      Being There
# 305          8.0                                       Persepolis
# 306          8.0                               This Is Spinal Tap
# 307          8.0                                     East of Eden
# 308          8.0                              Pink Floyd The Wall
# 309          8.0                                    Blood Diamond
# ...

# %%
m1[m1.star_rating.between(7,8)].count()
# Out:
# star_rating       682
# title             682
# content_rating    680
# genre             682
# duration          682
# actors_list       682
# dtype: int64

# %%
m1.star_rating.aggregate(['min','max','mean']) #it aggregrate the list
# Out:
# min     7.400000
# max     9.300000
# mean    7.889785
# Name: star_rating, dtype: float64

# %%
m1.star_rating.max()
# Out:
# 9.3

# %%
m1.star_rating.min()
# Out:
# 7.4

# %%
m1.star_rating.mean()
# Out:
# 7.8897854954034985

# %%
m1[m1.star_rating.between(9,9.3)]
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
m1[m1.star_rating==9.3] # max from the list
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
m2=m1.sort_values('duration',ascending='Fasle')

# %%
m2
# Out:
#      star_rating                                          title  \
# 389          8.0                                         Freaks
# 338          8.0                            Battleship Potemkin
# 258          8.1                    The Cabinet of Dr. Caligari
# 293          8.1                                      Duck Soup
# 88           8.4                                        The Kid
# 742          7.6                                      Following
# 351          8.0                                   Frankenstein
# 938          7.4                            Alice in Wonderland
# 405          7.9                      The Bride of Frankenstein
# 303          8.0                 The Nightmare Before Christmas
# 713          7.6                                The Jungle Book
# 864          7.5                                          [Rec]
# 489          7.8                     The Triplets of Belleville
# 535          7.8                                          Zelig
# ...
