# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
iris=load_iris()

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df['target']=iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.shape
# Out:
# (150, 5)

# %%
df.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# target                     0.956547  1.000000

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,8))
sns.boxplot(df['sepal length (cm)'])
plt.title('sepal length')
plt.grid()
plt.show()#sns shows allias

# %% [markdown]
# cbond having same use as matplotliberary but compairtativly less flexicible than matplot

# %%
plt.figure(figsize=(15,8))
sns.pairplot(df)

# %% [markdown]
# pair plot shows how many trend follow the ploted the graph

# %%
plt.figure(figsize=(15,8))
sns.distplot(df['sepal length (cm)'])
plt.grid()
plt.show()

# %% [markdown]
# distplot() having fuction to plot the distribution curve about the given data frame value

# %%
x=df.iloc[:,2:-1].values
y=df['target'].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=0)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=0)

# %% [markdown]
#  # max_depth
#  it shows how much depth values required from data frame

# %%
y_pred=dt.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-adbc0cf6b01c> in <module>
# ----> 1 y_pred=dt.predict(x_test)
#
# NameError: name 'dt' is not defined

# %%
print(dt.score(x_test,y_test))
dt.score(x_train,y_train)

# %%
np.where(y_test !=y_pred)

# %%
y_test[24]

# %%
from sklearn.tree import export_graphviz
import graphviz

# %%
dot_data=export_graphviz(dt,feature_names=iris.feature_names[2:],class_names=iris.target_names)

# %%
dot_data

# %%
import pydotplus
from IPython.display import Image

# %%
graph=pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %%
graph.write_png('13.1 Decision_Tree_Iris.png')

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=10)

# %%
rf.fit(x_train,y_train)

# %%
y_pred=rf.predict(x_test)

# %%
print(rf.score(x_train,y_train))
rf.score(x_test,y_test)

# %% [markdown]
# # random forest
#  it is more precise than decision tree because it give 10 values indiviually

# %% [markdown]
# * boot strap is nothing but it combine the value in decision tree
