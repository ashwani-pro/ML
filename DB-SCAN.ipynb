# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets.samples_generator import make_blobs

# %%
x,y= make_blobs(n_samples=400,centers=3,
               cluster_std=0.6,random_state=1)

# %%
plt.scatter(x[:,0],x[:,1])

# %%
 from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x_sc=scaler.fit_transform(x)
x_sc # standard scaler usually nothing but their mean values
# Out:
# array([[-1.43690498e+00, -2.56542067e-02],
#        [-1.36822781e+00, -2.11935774e-01],
#        [ 7.57131437e-01,  5.80535332e-01],
#        [ 4.90382679e-01,  1.33029780e+00],
#        [-1.13747697e-01,  8.66053199e-01],
#        [ 1.04015551e+00, -9.32961581e-01],
#        [ 1.21579511e+00, -1.24892095e+00],
#        [-1.42882301e+00,  5.86705959e-01],
#        [-1.45077953e+00,  5.99910773e-01],
#        [ 1.29283488e+00, -1.62589593e+00],
#        [ 1.44654142e-01,  1.82156413e+00],
#        [-1.48664930e+00,  1.12852754e-01],
#        [ 3.21842672e-01,  7.75373215e-01],
#        [-1.73818920e+00,  1.42688094e-01],
#        [ 7.94098366e-02,  9.23808317e-01],
#        [-1.37662818e-01,  1.36974515e+00],
#        [ 9.71459598e-01, -1.08539035e+00],
#        [ 9.59402830e-01, -1.42834899e+00],
#        [ 2.81238181e-01,  9.48030852e-01],
#        [ 1.18828450e+00, -1.20712483e+00],
#        [-1.14583896e+00,  2.88199831e-01],
#        [-1.55086324e+00, -1.93630850e-01],
# ...

# %%
from sklearn.cluster import DBSCAN
dbscan=DBSCAN(eps=0.3,metric='euclidean',min_samples=10)

# %%
cluster=dbscan.fit_predict(x_sc)

# %%
dbscan.labels_
# Out:
# array([ 0,  0,  1,  1,  1,  2,  2,  0,  0,  2,  1,  0,  1,  0,  1,  1,  2,
#         2,  1,  2,  0,  0,  1,  0,  0,  2,  0,  2,  1,  1,  2,  0, -1,  2,
#         0,  2,  1,  1,  2,  0, -1,  2,  2,  0,  1,  1, -1,  2,  1,  0,  0,
#         1,  2,  1, -1,  1,  0,  1,  0,  2,  1,  2,  0,  2,  0,  0, -1,  0,
#         1,  1,  2,  2,  0,  0,  1,  0,  2,  1,  2,  1,  1,  0,  2,  0,  2,
#         1,  0,  2,  2,  1,  1, -1, -1,  0,  1, -1,  1,  0,  0,  1,  2,  2,
#         2,  0,  2,  1,  2,  2,  0,  2,  2,  0,  0,  0, -1,  0,  1,  0,  0,
#         2,  2,  1, -1,  2,  1,  0,  2, -1,  2,  2,  0,  1,  2,  0,  1,  0,
#         2,  1,  0,  0,  0,  2,  0,  1,  2,  1,  2,  2,  1,  2,  1,  0,  0,
#         1,  0,  0,  2,  1,  0,  0,  0,  2,  0,  2,  0,  2,  0,  0,  0,  2,
#         2,  0,  1,  2,  1,  0,  1, -1, -1,  0,  2,  2,  1,  1,  2,  1,  1,
#         0,  2,  0,  0,  2,  2,  1,  1,  0,  1,  2,  0,  1,  2,  0,  1,  0,
# ...

# %% [markdown]
# # DBSCAN
#      it plot the noise of the cluster ie. denoted by -1
